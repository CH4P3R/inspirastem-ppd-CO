# %% [markdown]
# ## Introducción a Jupyter Notebooks
# ___

# %% [markdown]
# ## Cómo usar esta Guía
#
# La página web en la que te encuentras es en realidad una aplicación llamada Jupyter Notebook. Una celda de *entrada/input* parece un cuadro gris claro con un `In [ ] ` a su izquierda. Cada una de las celdas de entrada contiene códigos: instrucciones para hacer que el computador haga algo.
#
# Para activar o seleccionar una celda, haz clic en cualquier lugar dentro de ella.
#
# <div class='alert alert-info'>
#     <font size='3'><b>Selecciona la celda de abajo y lee su contenido.</b></font>
# </div>

# %% [markdown]
# # Tabla de Contenidos
#
# * [Cómo usar esta Guía](#How-to-Use-This-Notebook)
# * [Configuración Previa a la Actividad](#Pre-Activity-Setup)
# ___

# %%
# El texto que sigue a un "#" es un comentario.
# Los comentarios no afectan su código de ninguna manera.
# Lea siempre los comentarios en la parte superior de cada celda con la que interactúe.
# Los comentarios se utilizarán para describir lo que realmente está haciendo el código de la celda.

# %% [markdown]
# Para ejecutar una celda seleccionada, haz clic en el pequeño botón de reproducción o presiona `[Shift + Enter]` en tu teclado.
#
#
# <div class='alert alert-info'>
#     <font size='3'><b>Selecciona la celda de abajo y lee su contenido. Luego, ejecuta la celda.</b></font>
#         <br> Si aparece una advertencia, simplemente haz clic en <em>"Ejecutar de todos modos"</em>, este código es seguro 😉
#         <br> Además, si deseas guardar tu progreso, haz clic en el botón <em>"Guardar una copia en Drive"</em> en la parte superior.
#       </div>

# %%
# El texto que NO está antecedido por un "#" se considera código.
# Las líneas de código son instrucciones dadas a tu computador.
# La línea de código de abajo es una instrucción de "impresión" (print), que literalmente imprime el texto entre comillas.

print("¡Felicitaciones! ¡Has ejecutado con éxito tu primera celda!")
# Out:
# ¡Felicitaciones! ¡Has ejecutado con éxito tu primera celda!

# %% [markdown]
# Ejecutar una celda crea una *salida/output* directamente debajo de ella. Una salida puede ser un texto, un gráfico, un control deslizante interactivo, ¡o incluso nada en absoluto! Cuando has ejecutado una celda, aparece un número entre corchetes, por ejemplo [1] al lado izquierdo de la celda.
#
# <div class='alert alert-info'>
#     <font size='3'><b>Abre todas las secciones de este bloc de notas seleccionando el menú "Ver" y "Expandir secciones" </b></font>
#         <br>
# </div>
#
#
# Puedes obtener más información sobre cómo funcionan los Jupyter Notebooks en https://try.jupyter.org/ (página en inglés)
# ___

# %% [markdown]
# # Configuración Previa a la Actividad
#
# Para que cualquiera de las actividades funcione correctamente, debes importar las librerias necesarias para el funcionamiento del código de esta guía. Estos ya deberían haberse cargado cuando ejecutaste todas las celdas.
#
# <div class='alert alert-info'>
#     <font size='3'><b>Selecciona y ejecuta la celda a continuación.</b></font>
# </div>

# %%
# Clonar el repositorio de GitHub e importar los módulos necesarios usando requisitos.txt.

# !git clone https://github.com/mas-astro/inspirastem-ppd-CO
# Out:
# Clonando en 'inspirastem-ppd-CO'...
# remote: Enumerating objects: 201, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 201 (delta 42), reused 12 (delta 12), pack-reused 153 (from 1)
# Recibiendo objetos: 100% (201/201), 2.91 MiB | 4.30 MiB/s, listo.
# Resolviendo deltas: 100% (88/88), listo.

# %% [markdown]
# Este comando te indica la ruta del archivo de tu ubicación actual. En este caso, debería ser `content/`.

# %%
# !pwd
# Out:
# /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/00_antecurso

# %% [markdown]
# El siguiente comando te muestra el contenido del directorio en el que te encuentras actualmente. Debería contener el repositorio de GitHub que acabamos de clonar: `inspirastem-ppd-CO`.

# %%
# !ls
# Out:
# inspirastem-ppd-CO  Intro_Jupyter_Notebooks.ipynb  README.md

# %%
# cambiamos directorio con %cd
# %cd inspirastem-ppd-CO
# Out:
# /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/00_antecurso/inspirastem-ppd-CO

# %% [markdown]
# Ahora, importaremos las librerias y los paquetes necesarios para nuestras actividades y ejercicios.

# %%
# AVISO: Al ejecutar esta celda, es posible que aparezca
# un mensaje pidiéndote que reinicies la sesión. Esto es
# normal y podrás volver a ejecutar las celdas.

# !pip install -r 00_antecurso/requisitos.txt
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import cm
from IPython.display import display, HTML
import warnings
warnings.filterwarnings("ignore")

print('¡Listo! Has importado correctamente las bibliotecas.')
# Out:
# Requirement already satisfied: numpy in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from -r 00_antecurso/requisitos.txt (line 2)) (2.5.3)
# Requirement already satisfied: pandas in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from -r 00_antecurso/requisitos.txt (line 3)) (3.0.6)
# Requirement already satisfied: scipy in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from -r 00_antecurso/requisitos.txt (line 4)) (1.18.1)
# Requirement already satisfied: astropy in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from -r 00_antecurso/requisitos.txt (line 5)) (8.0.1)
# Requirement already satisfied: matplotlib in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from -r 00_antecurso/requisitos.txt (line 6)) (3.11.2)
# Requirement already satisfied: mpl-interactions in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from -r 00_antecurso/requisitos.txt (line 7)) (0.24.2)
# Requirement already satisfied: plotly in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from -r 00_antecurso/requisitos.txt (line 8)) (7.1.0)
# Requirement already satisfied: specutils in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from -r 00_antecurso/requisitos.txt (line 9)) (2.4.0)
# Requirement already satisfied: statistics in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from -r 00_antecurso/requisitos.txt (line 10)) (1.0.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from pandas->-r 00_antecurso/requisitos.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: astropy-iers-data>=0.2026.6.22.1.23.34 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from astropy->-r 00_antecurso/requisitos.txt (line 5)) (0.2026.9.14.0.56.43)
# Requirement already satisfied: packaging>=25.0 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from astropy->-r 00_antecurso/requisitos.txt (line 5)) (26.3)
# Requirement already satisfied: pyerfa>=2.0.1.3 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from astropy->-r 00_antecurso/requisitos.txt (line 5)) (2.0.1.5)
# Requirement already satisfied: PyYAML>=6.0.0 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from astropy->-r 00_antecurso/requisitos.txt (line 5)) (6.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from matplotlib->-r 00_antecurso/requisitos.txt (line 6)) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from matplotlib->-r 00_antecurso/requisitos.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from matplotlib->-r 00_antecurso/requisitos.txt (line 6)) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from matplotlib->-r 00_antecurso/requisitos.txt (line 6)) (1.5.1)
# Requirement already satisfied: pillow>=9 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from matplotlib->-r 00_antecurso/requisitos.txt (line 6)) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from matplotlib->-r 00_antecurso/requisitos.txt (line 6)) (3.3.2)
# Requirement already satisfied: narwhals>=1.15.1 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from plotly->-r 00_antecurso/requisitos.txt (line 8)) (2.26.0)
# Requirement already satisfied: gwcs>=0.25.1 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from specutils->-r 00_antecurso/requisitos.txt (line 9)) (1.0.3)
# Requirement already satisfied: asdf-astropy>=0.8 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from specutils->-r 00_antecurso/requisitos.txt (line 9)) (0.11.0)
# Requirement already satisfied: asdf>=3.3.0 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from specutils->-r 00_antecurso/requisitos.txt (line 9)) (5.4.0)
# Requirement already satisfied: ndcube>=2.0 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from specutils->-r 00_antecurso/requisitos.txt (line 9)) (2.4.2)
# Requirement already satisfied: docutils>=0.3 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from statistics->-r 00_antecurso/requisitos.txt (line 10)) (0.23)
# Requirement already satisfied: asdf-standard>=1.1.0 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from asdf>=3.3.0->specutils->-r 00_antecurso/requisitos.txt (line 9)) (1.5.0)
# Requirement already satisfied: jmespath>=0.6.2 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from asdf>=3.3.0->specutils->-r 00_antecurso/requisitos.txt (line 9)) (1.1.0)
# Requirement already satisfied: semantic_version>=2.8 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from asdf>=3.3.0->specutils->-r 00_antecurso/requisitos.txt (line 9)) (2.10.0)
# Requirement already satisfied: typing-extensions>=4.16 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from asdf>=3.3.0->specutils->-r 00_antecurso/requisitos.txt (line 9)) (4.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from asdf>=3.3.0->specutils->-r 00_antecurso/requisitos.txt (line 9)) (26.1.0)
# Requirement already satisfied: asdf-coordinates-schemas>=0.4 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from asdf-astropy>=0.8->specutils->-r 00_antecurso/requisitos.txt (line 9)) (0.5.1)
# Requirement already satisfied: asdf-transform-schemas>=0.6 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from asdf-astropy>=0.8->specutils->-r 00_antecurso/requisitos.txt (line 9)) (0.6.0)
# Requirement already satisfied: asdf_wcs_schemas>=0.5.0 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from gwcs>=0.25.1->specutils->-r 00_antecurso/requisitos.txt (line 9)) (0.5.0)
# Requirement already satisfied: six>=1.5 in /home/chaper/Dev/InspiraStem2026/inspirastem-ppd-CO/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->-r 00_antecurso/requisitos.txt (line 3)) (1.17.0)
# ¡Listo! Has importado correctamente las bibliotecas.

# %% [markdown]
# ### Nota al margen de programación
#
# Las celdas anteriores son una forma de importar las funciones necesarias y otras cosas que nos permiten hacer dibujos y operaciones matemáticas con mucha facilidad. En la siguiente celda, usaremos un diccionario para agrupar cosas fácilmente. Así como en un diccionario normal hay una palabra y una definición, este diccionario actúa de manera similar pero en lugar de una palabra, lo llamamos clave y en lugar de una definición lo llamamos valor.
#
#
# ```python
# dictionary = {key1 : value1, key2 : value2 ...}
# ```

# %%
#Defina algunas preferencias de visualización de imágenes en un "objeto de diccionario", para usar durante la actividad:
myargs = {'interpolation': 'nearest', 'origin': 'lower', 'cmap': cm.nipy_spectral}
# La siguiente línea de comando especifica un mapa de color alternativo, que algunos pueden encontrar más cómodo para trabajar.
# Descomente y ejecute la siguiente línea si desea usarla:
myargs = {'interpolation': 'nearest', 'origin': 'lower', 'cmap': cm.hot}

# %% [markdown]
# ___
