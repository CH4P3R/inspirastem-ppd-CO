# %% [markdown]
# # InspiraSTEM Día 1 - Introducción a Discos Protoplanetarios
#
# ### 19 septiembre 2026
#
# # Actividad 1: Espectra Molecular
# *Tiempo estimado: 10 minutos*
#
# Con lo que hemos aprendido, ahora te toca a ti analizar el disco que se te ha asignado para realizar observaciones científicas que te ayuden a orientar tu comprensión de cara al próximo análisis. La información se almacena en un archivo de imagen especializado llamado archivo FITS, que significa «Flexible Image Transport System» (Sistema Flexible de Transporte de Imágenes). Es el formato estándar para los datos de imágenes astronómicas y muchos (si no todos) los paquetes de software astronómico se basan en este tipo de imagen.
#
# Para leer este archivo de imagen y visualizar e interpretar su contenido, utilizamos el paquete `astropy`. Este contiene la gran mayoría de las herramientas útiles que los astrónomos utilizan a lo largo de sus análisis — y, de hecho, también las nuestras.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/bb/Carbon_monoxide_rotational-vibrational_spectrum.png?utm_source=commons.wikimedia.org&utm_campaign=index&utm_content=original" style="width: 500px;">
#
# *Instrucciones*: Cargarás los espectros de tu disco, utilizarás las herramientas de trazado integradas y ajustarás los rangos de los gráficos para ampliar la imagen y analizar líneas individuales de los datos sin procesar.
# A partir de esto, debes tomar nota de cualquier cosa interesante, anómala o que te genere dudas. Aquí hay algunas preguntas para guiar tu investigación:
#
# *   ¿Qué tipo de formas de líneas ves?
# *   ¿Eso te dice algo sobre la fuente que genera esta emisión?
# *   ¿Qué otras características notas que son más destacadas?
# *   ¿En qué longitudes de onda comienzan y terminan tus espectros?
#
# Aunque estas preguntas tienen como objetivo hacerte pensar en las características espectrales, elaboren sus propias notas en grupo para que las discutamos juntos.

# %% [markdown]
# Primero debemos clonar el repositorio de GitHub para acceder a los datos y a la estructura de directorios:

# %%
## !git clone https://github.com/mas-astro/inspirastem-ppd-CO

# %%
# Revisando en cual directorio nos encontramos

## !pwd

# %%
# Cambiamos directorio con %cd

## %cd /content/inspirastem-ppd-CO

# %%
# Nos aseguramos de los contenidos del directorio inspirastem-ppd-CO/

## !ls

# %%
# AVISO: Al ejecutar esta celda, es posible que aparezca
# un mensaje pidiéndote que reinicies la sesión. Esto es
# normal y podrás volver a ejecutar las celdas.

# pip install -r requirements.txt
import os
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import cm
from astropy.io import fits
import astropy.units as u
from astropy import constants as const

from IPython.display import display, HTML
import warnings
warnings.filterwarnings("ignore")

print('¡Listo! Has importado correctamente las bibliotecas.')
# Out:
# ¡Listo! Has importado correctamente las bibliotecas.

# %% [markdown]
# El nombre del archivo FITS de tu disco va aqui. AA Tau esta usado como ejemplo, pero debes reemplazar el "AATau" por los nombres de los archivos de tu disco.

# %%
nom_disco = 'EXLup14_M.fits'
# nom_per_apil = 'DRTau_COv1-0stacked.fits'

# %% [markdown]
# Lo siguiente abrirá el archivo FITS y accederá a su contenido para que podamos representarlo gráficamente y utilizarlo más adelante en el código.

# %%
import os
from astropy.io import fits
import astropy.units as u
from astropy import constants as const
from astropy.nddata import StdDevUncertainty
from specutils import Spectrum1D

# Ruta base flexible que funciona tanto en Google Colab como localmente
if os.path.exists('data'):
    base_data_path = 'data'
elif os.path.exists('../data'):
    base_data_path = '../data'
elif os.path.exists('/content/inspirastem-ppd-CO/data'):
    base_data_path = '/content/inspirastem-ppd-CO/data'
else:
    base_data_path = 'data'

disk_path = os.path.join(base_data_path, 'discos', '')
stacked_path = os.path.join(base_data_path, 'lineas_apiladas', '')
CO_lines = os.path.join(base_data_path, 'HITRAN_CO_lineas.xlsx')

c_u = (const.c.value * 1e6) * (u.micron / u.s)   # speed of light in [um/s]
COlines_df = pd.read_excel(CO_lines, sheet_name="COlineranges")

# CO SPECTRAL DATA: (um,Jy)
with fits.open(disk_path + nom_disco) as hdu1:
  specdata = hdu1[1].data[0]   # opens .fits files

wv = np.asarray(specdata[0] * 1e-3, dtype=np.float64) # converting to micron from nm
fln = np.asarray(specdata[1], dtype=np.float64)
err_data = np.asarray(specdata[2], dtype=np.float64)
err = StdDevUncertainty(err_data, unit = 'Jy')
m_spec = Spectrum1D(flux=fln*u.Jy, spectral_axis=wv*u.micron, uncertainty=err)

# %% [markdown]
# Aquí estamos representando los datos directamente. Examina los espectros con las herramientas que se encuentran en la esquina superior derecha del gráfico.

# %%
import plotly.express as px

data_dict = {'Wavelength [μm]': wv, 'Flux [Jy]': fln}#, 'uncertainty': [err]}
plot = px.line(pd.DataFrame(data_dict), x='Wavelength [μm]', y="Flux [Jy]",
              title=f"CO spectra: {nom_disco}")

plot.show(config={'scrollZoom': True})
